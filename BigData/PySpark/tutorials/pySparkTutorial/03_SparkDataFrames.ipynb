# %% [markdown]
# # Spark DataFrames
#
# Last part of https://towardsdatascience.com/the-hitchhikers-guide-to-handle-big-data-using-spark-90b9be0fe89a

# %%
# File 'data' is a CSV that uses TAB as separator and does not have header
#ratings = spark.read.load("Data-ML-100k--master/ml-100k/u.data",format="csv", sep="\t", inferSchema="true", header="false")
ratings = spark.read.load("/FileStore/tables/u.data",format="csv", sep="\t", inferSchema="true", header="false")
ratings.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+---+---------+
# _c0|_c1|_c2|      _c3|
# +---+---+---+---------+
# 196|242|  3|881250949|
# 186|302|  3|891717742|
#  22|377|  1|878887116|
# +---+---+---+---------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### Change Column names / Add header
# Good functionality. Always required. Don’t forget the * in front of the list.

# %%
ratings = ratings.toDF(*['user_id', 'movie_id', 'rating', 'unix_timestamp'])
ratings.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+------+--------------+
# user_id|movie_id|rating|unix_timestamp|
# +-------+--------+------+--------------+
#     196|     242|     3|     881250949|
#     186|     302|     3|     891717742|
#      22|     377|     1|     878887116|
# +-------+--------+------+--------------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### Some basic stats

# %%
print(ratings.count()) #Row Count
print(len(ratings.columns)) #Column Count
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">100000
# 4
# </div>

# %% [markdown]
# ## Different ways to present the data
# * display
# * show()
# * toPandas()
# * collect(): Whole DF to list
# * take(n): Same as above but only 'n' rows

# %%
display(ratings.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>user_id</th><th>movie_id</th><th>rating</th><th>unix_timestamp</th></tr></thead><tbody><tr><td>count</td><td>100000</td><td>100000</td><td>100000</td><td>100000</td></tr><tr><td>mean</td><td>462.48475</td><td>425.53013</td><td>3.52986</td><td>8.8352885148862E8</td></tr><tr><td>stddev</td><td>266.61442012750905</td><td>330.79835632558473</td><td>1.1256735991443214</td><td>5343856.189502848</td></tr><tr><td>min</td><td>1</td><td>1</td><td>1</td><td>874724710</td></tr><tr><td>max</td><td>943</td><td>1682</td><td>5</td><td>893286638</td></tr></tbody></table></div>

# %%
ratings.describe().show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+------------------+------------------+-----------------+
# summary|           user_id|          movie_id|            rating|   unix_timestamp|
# +-------+------------------+------------------+------------------+-----------------+
#   count|            100000|            100000|            100000|           100000|
#    mean|         462.48475|         425.53013|           3.52986|8.8352885148862E8|
#  stddev|266.61442012750905|330.79835632558473|1.1256735991443214|5343856.189502848|
#     min|                 1|                 1|                 1|        874724710|
#     max|               943|              1682|                 5|        893286638|
# +-------+------------------+------------------+------------------+-----------------+
#
# </div>

# %%
ratings.describe().toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>user_id</th>
#       <th>movie_id</th>
#       <th>rating</th>
#       <th>unix_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>count</td>
#       <td>100000</td>
#       <td>100000</td>
#       <td>100000</td>
#       <td>100000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mean</td>
#       <td>462.48475</td>
#       <td>425.53013</td>
#       <td>3.52986</td>
#       <td>8.8352885148862E8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stddev</td>
#       <td>266.61442012750905</td>
#       <td>330.79835632558473</td>
#       <td>1.1256735991443214</td>
#       <td>5343856.189502848</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>min</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>874724710</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>max</td>
#       <td>943</td>
#       <td>1682</td>
#       <td>5</td>
#       <td>893286638</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cr = ratings.describe().collect()
type(cr)            # --> list

#for row in cr:
#  print(row)
  # print(type(row))     # <class 'pyspark.sql.types.Row'>
  # print(f"Mean is:{row[1]}")
  #for res in row:
  #  print(res)
  
[print(row) for row in cr]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Row(summary=&#39;count&#39;, user_id=&#39;100000&#39;, movie_id=&#39;100000&#39;, rating=&#39;100000&#39;, unix_timestamp=&#39;100000&#39;)
# Row(summary=&#39;mean&#39;, user_id=&#39;462.48475&#39;, movie_id=&#39;425.53013&#39;, rating=&#39;3.52986&#39;, unix_timestamp=&#39;8.8352885148862E8&#39;)
# Row(summary=&#39;stddev&#39;, user_id=&#39;266.61442012750905&#39;, movie_id=&#39;330.79835632558473&#39;, rating=&#39;1.1256735991443214&#39;, unix_timestamp=&#39;5343856.189502848&#39;)
# Row(summary=&#39;min&#39;, user_id=&#39;1&#39;, movie_id=&#39;1&#39;, rating=&#39;1&#39;, unix_timestamp=&#39;874724710&#39;)
# Row(summary=&#39;max&#39;, user_id=&#39;943&#39;, movie_id=&#39;1682&#39;, rating=&#39;5&#39;, unix_timestamp=&#39;893286638&#39;)
# Out[11]: [None, None, None, None, None]</div>

# %%
ratings.describe().take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [Row(summary=&#39;count&#39;, user_id=&#39;100000&#39;, movie_id=&#39;100000&#39;, rating=&#39;100000&#39;, unix_timestamp=&#39;100000&#39;),
#  Row(summary=&#39;mean&#39;, user_id=&#39;462.48475&#39;, movie_id=&#39;425.53013&#39;, rating=&#39;3.52986&#39;, unix_timestamp=&#39;8.8352885148862E8&#39;),
#  Row(summary=&#39;stddev&#39;, user_id=&#39;266.61442012750905&#39;, movie_id=&#39;330.79835632558473&#39;, rating=&#39;1.1256735991443214&#39;, unix_timestamp=&#39;5343856.189502848&#39;),
#  Row(summary=&#39;min&#39;, user_id=&#39;1&#39;, movie_id=&#39;1&#39;, rating=&#39;1&#39;, unix_timestamp=&#39;874724710&#39;),
#  Row(summary=&#39;max&#39;, user_id=&#39;943&#39;, movie_id=&#39;1682&#39;, rating=&#39;5&#39;, unix_timestamp=&#39;893286638&#39;)]</div>

# %%
ratings.select('user_id','movie_id').show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+
# user_id|movie_id|
# +-------+--------+
#     196|     242|
#     186|     302|
#      22|     377|
# +-------+--------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### Filter
# Filter a dataframe using multiple conditions:

# %%
ratings.filter((ratings.rating==5) & (ratings.user_id==253)).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+------+--------------+
# user_id|movie_id|rating|unix_timestamp|
# +-------+--------+------+--------------+
#     253|     465|     5|     891628467|
#     253|     510|     5|     891628416|
#     253|     183|     5|     891628341|
# +-------+--------+------+--------------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### Groupby
# We can use groupby function with a spark dataframe too.
#
# Pretty much same as a pandas groupby with the exception that you will need to import pyspark.sql.functions

# %%
from pyspark.sql import functions as F
ratings.groupBy("user_id").agg(F.count("user_id"),F.mean("rating")).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------+------------------+
# user_id|count(user_id)|       avg(rating)|
# +-------+--------------+------------------+
#     148|            65|               4.0|
#     463|           133|2.8646616541353382|
#     471|            31|3.3870967741935485|
# +-------+--------------+------------------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### Sort

# %%
ratings.sort("user_id").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+------+--------------+
# user_id|movie_id|rating|unix_timestamp|
# +-------+--------+------+--------------+
#       1|      33|     4|     878542699|
#       1|     202|     5|     875072442|
#       1|     160|     4|     875072547|
#       1|      61|     4|     878542420|
#       1|     189|     3|     888732928|
# +-------+--------+------+--------------+
# only showing top 5 rows
#
# </div>

# %%
# descending Sort
from pyspark.sql import functions as F
ratings.sort(F.desc("user_id")).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+------+--------------+
# user_id|movie_id|rating|unix_timestamp|
# +-------+--------+------+--------------+
#     943|     570|     1|     888640125|
#     943|     186|     5|     888639478|
#     943|     232|     4|     888639867|
#     943|      58|     4|     888639118|
#     943|    1067|     2|     875501756|
# +-------+--------+------+--------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ## Joins/Merging with Spark Dataframes
#
# I was not able to find a pandas equivalent of merge with Spark DataFrames but we can use SQL with dataframes and thus we can merge dataframes using SQL.
#
# Let us try to run some SQL on Ratings.
#
# We first register the ratings df to a temporary table ratings_table on which we can run sql operations.
#
# As you can see the result of the SQL select statement is again a Spark Dataframe.

# %%
ratings.registerTempTable('ratings_table')
newDF = spark.sql('select * from ratings_table where rating>4')
display(newDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>movie_id</th><th>rating</th><th>unix_timestamp</th></tr></thead><tbody><tr><td>253</td><td>465</td><td>5</td><td>891628467</td></tr><tr><td>286</td><td>1014</td><td>5</td><td>879781125</td></tr><tr><td>200</td><td>222</td><td>5</td><td>876042340</td></tr><tr><td>122</td><td>387</td><td>5</td><td>879270459</td></tr><tr><td>38</td><td>95</td><td>5</td><td>892430094</td></tr><tr><td>160</td><td>234</td><td>5</td><td>876861185</td></tr><tr><td>278</td><td>603</td><td>5</td><td>891295330</td></tr><tr><td>287</td><td>327</td><td>5</td><td>875333916</td></tr><tr><td>246</td><td>201</td><td>5</td><td>884921594</td></tr><tr><td>242</td><td>1137</td><td>5</td><td>879741196</td></tr><tr><td>249</td><td>241</td><td>5</td><td>879641194</td></tr><tr><td>99</td><td>4</td><td>5</td><td>886519097</td></tr><tr><td>25</td><td>181</td><td>5</td><td>885853415</td></tr><tr><td>59</td><td>196</td><td>5</td><td>888205088</td></tr><tr><td>290</td><td>143</td><td>5</td><td>880474293</td></tr><tr><td>42</td><td>423</td><td>5</td><td>881107687</td></tr><tr><td>138</td><td>26</td><td>5</td><td>879024232</td></tr><tr><td>60</td><td>427</td><td>5</td><td>883326620</td></tr><tr><td>57</td><td>304</td><td>5</td><td>883698581</td></tr><tr><td>127</td><td>229</td><td>5</td><td>884364867</td></tr><tr><td>225</td><td>237</td><td>5</td><td>879539643</td></tr><tr><td>225</td><td>480</td><td>5</td><td>879540748</td></tr><tr><td>291</td><td>144</td><td>5</td><td>874835091</td></tr><tr><td>267</td><td>518</td><td>5</td><td>878971773</td></tr><tr><td>279</td><td>154</td><td>5</td><td>875296291</td></tr><tr><td>119</td><td>1153</td><td>5</td><td>874781198</td></tr><tr><td>90</td><td>382</td><td>5</td><td>891383835</td></tr><tr><td>166</td><td>328</td><td>5</td><td>886397722</td></tr><tr><td>271</td><td>132</td><td>5</td><td>885848672</td></tr><tr><td>160</td><td>174</td><td>5</td><td>876860807</td></tr><tr><td>42</td><td>96</td><td>5</td><td>881107178</td></tr><tr><td>168</td><td>151</td><td>5</td><td>884288058</td></tr><tr><td>44</td><td>195</td><td>5</td><td>878347874</td></tr><tr><td>264</td><td>200</td><td>5</td><td>886122352</td></t
>4</td></tr><tr><td>1081</td><td>Curdled (1996)</td><td>1</td></tr><tr><td>603</td><td>Rear Window (1954)</td><td>5</td></tr><tr><td>796</td><td>Speechless (1994)</td><td>1</td></tr><tr><td>32</td><td>Crumb (1994)</td><td>4</td></tr><tr><td>16</td><td>French Twist (Gazon maudit) (1995)</td><td>4</td></tr><tr><td>304</td><td>Fly Away Home (1996)</td><td>4</td></tr><tr><td>979</td><td>Trigger Effect, The (1996)</td><td>2</td></tr><tr><td>564</td><td>Tales from the Hood (1995)</td><td>3</td></tr><tr><td>327</td><td>Cop Land (1997)</td><td>5</td></tr><tr><td>201</td><td>Evil Dead II (1987)</td><td>5</td></tr><tr><td>1137</td><td>Beautiful Thing (1996)</td><td>5</td></tr><tr><td>241</td><td>Last of the Mohicans, The (1992)</td><td>5</td></tr><tr><td>4</td><td>Get Shorty (1995)</td><td>5</td></tr><tr><td>332</td><td>Kiss the Girls (1997)</td><td>3</td></tr><tr><td>100</td><td>Fargo (1996)</td><td>4</td></tr><tr><td>432</td><td>Fantasia (1940)</td><td>2</td></tr><tr><td>322</td><td>Murder at 1600 (1997)</td><td>4</td></tr><tr><td>181</td><td>Return of the Jedi (1983)</td><td>5</td></tr><tr><td>196</td><td>Dead Poets Society (1989)</td><td>5</td></tr><tr><td>679</td><td>Conan the Barbarian (1981)</td><td>2</td></tr><tr><td>384</td><td>Naked Gun 33 1/3: The Final Insult (1994)</td><td>4</td></tr><tr><td>143</td><td>Sound of Music, The (1965)</td><td>5</td></tr><tr><td>423</td><td>E.T. the Extra-Terrestrial (1982)</td><td>5</td></tr><tr><td>515</td><td>Boot, Das (1981)</td><td>4</td></tr><tr><td>20</td><td>Angels and Insects (1995)</t ...

# %%
# 1st
# display(ratings.alias('r').join(movies, ratings.movie_id == movies.movie_id, how='inner').select("r.movie_id","movie_title", "rating"))

# 2nd
#sel_columns = ["r.movie_id", "movie_title", "rating"]
#display(ratings.alias('r').join(movies, ratings.movie_id == movies.movie_id, how='inner').select(sel_columns))

# 3rd
sel_columns = "r.movie_id", "movie_title", "rating"
display(ratings.alias('r').join(movies, ratings.movie_id == movies.movie_id, how='inner').select(*sel_columns))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movie_id</th><th>movie_title</th><th>rating</th></tr></thead><tbody><tr><td>242</td><td>Kolya (1996)</td><td>3</td></tr><tr><td>302</td><td>L.A. Confidential (1997)</td><td>3</td></tr><tr><td>377</td><td>Heavyweights (1994)</td><td>1</td></tr><tr><td>51</td><td>Legends of the Fall (1994)</td><td>2</td></tr><tr><td>346</td><td>Jackie Brown (1997)</td><td>1</td></tr><tr><td>474</td><td>Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)</td><td>4</td></tr><tr><td>265</td><td>Hunt for Red October, The (1990)</td><td>2</td></tr><tr><td>465</td><td>Jungle Book, The (1994)</td><td>5</td></tr><tr><td>451</td><td>Grease (1978)</td><td>3</td></tr><tr><td>86</td><td>Remains of the Day, The (1993)</td><td>3</td></tr><tr><td>257</td><td>Men in Black (1997)</td><td>2</td></tr><tr><td>1014</td><td>Romy and Michele's High School Reunion (1997)</td><td>5</td></tr><tr><td>222</td><td>Star Trek: First Contact (1996)</td><td>5</td></tr><tr><td>40</td><td>To Wong Foo, Thanks for Everything! Julie Newm